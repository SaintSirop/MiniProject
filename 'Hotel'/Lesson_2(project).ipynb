# %% [markdown]
# # Чуйкин Никита
# # Минипроект 'Hotel'

# %% [markdown]
# # Задачи:

# %% [markdown]
# 1) Импортируйте библиотеку pandas как pd. Загрузите датасет bookings.csv с разделителем ;. Проверьте размер таблицы, типы переменных, а затем выведите первые 7 строк, чтобы посмотреть на данные.
#
# 2) Приведите названия колонок к нижнему регистру и замените пробелы на знак нижнего подчеркивания.
#
# 3) Пользователи из каких стран совершили наибольшее число успешных бронирований? Укажите топ-5.
#
# 4) На сколько ночей в среднем бронируют отели разных типов?
#
# 5) Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга. Сколько подобных наблюдений встретилось в датасете?
#
# 6) Проанализируйте даты запланированного прибытия. – На какой месяц чаще всего успешно оформляли бронь в 2016? Изменился ли самый популярный месяц в 2017?– Сгруппируйте данные по годам и проверьте, на какой месяц бронирования отеля типа City Hotel отменялись чаще всего в каждый из периодов
#
# 7) Посмотрите на числовые характеристики трёх переменных: adults, children и babies. Какая из них имеет наибольшее среднее значение?
#
# 8) Создайте колонку total_kids, объединив children и babies. Для отелей какого типа среднее значение переменной оказалось наибольшим?
#
# 9) Создайте переменную has_kids, которая принимает значение True, если клиент при бронировании указал хотя бы одного ребенка (total_kids), в противном случае – False. Посчитайте отношение количества ушедших пользователей к общему количеству клиентов, выраженное в процентах (метрика - churn rate). Укажите, среди какой группы показатель выше.

# %% [markdown]
# # Задание № 1
# Импортируйте библиотеку pandas как pd. Загрузите датасет bookings.csv с разделителем ;. Проверьте размер таблицы, типы переменных, а затем выведите первые 7 строк, чтобы посмотреть на данные.

# %%
import pandas as pd

# %%
bookings = pd.read_csv('/home/jupyter-n-chujkin/shared/homeworks/python_ds_miniprojects/2/bookings.csv', sep=';')

# %%
bookings_head = bookings.head(7)

# %%
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
# 5               July                        27                          1
# 6               July                        27                          1
#
#    Stays in Weekend nights  Stays in week nights  ...  Adults  Children  \
# 0                        0                     0  ...       2       0.0
# 1                        0                     0  ...       2       0.0
# 2                        0                     1  ...       1       0.0
# 3                        0                     1  ...       1       0.0
# 4                        0                     2  ...       2       0.0
# 5                        0                     2  ...       2       0.0
# 6                        0                     2  ...       2       0.0
#
#    Babies  Meal Country Reserved Room Type Assigned room type customer type  \
# 0       0    BB     PRT                  C                  C     Transient
# 1       0    BB     PRT                  C                  C     Transient
# 2       0    BB     GBR                  A                  C     Transient
# 3       0    BB     GBR                  A                  A     Transient
# 4       0    BB     GBR                  A                  A     Transient
# 5       0    BB     GBR                  A                  A     Transient
# 6       0    BB     PRT                  C                  C     Transient
#
#   Reservation Status Reservation status_date
# 0          Check-Out              2015-07-01
# 1          Check-Out              2015-07-01
# 2          Check-Out              2015-07-02
# 3          Check-Out              2015-07-02
# 4          Check-Out              2015-07-03
# 5          Check-Out              2015-07-03
# 6          Check-Out              2015-07-03
#
# [7 rows x 21 columns]

# %%
bookings_head.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings
# Out:
#                Hotel  Is Canceled  Lead Time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         Arrival Date Year Arrival Date Month  Arrival Date Week Number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# 2                    2015               July                        27
# 3                    2015               July                        27
# 4                    2015               July                        27
# ...                   ...                ...                       ...
# 119385               2017             August                        35
# 119386               2017             August                        35
# 119387               2017             August                        35
# 119388               2017             August                        35
# 119389               2017             August                        35
#
#         Arrival Date Day of Month  Stays in Weekend nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         Stays in week nights  ...  Adults  Children  Babies  Meal Country  \
# 0                          0  ...       2       0.0       0    BB     PRT
# 1                          0  ...       2       0.0       0    BB     PRT
# 2                          1  ...       1       0.0       0    BB     GBR
# 3                          1  ...       1       0.0       0    BB     GBR
# 4                          2  ...       2       0.0       0    BB     GBR
# ...                      ...  ...     ...       ...     ...   ...     ...
# 119385                     5  ...       2       0.0       0    BB     BEL
# 119386                     5  ...       3       0.0       0    BB     FRA
# 119387                     5  ...       2       0.0       0    BB     DEU
# 119388                     5  ...       2       0.0       0    BB     GBR
# 119389                     7  ...       2       0.0       0    HB     DEU
#
#        Reserved Room Type Assigned room type customer type Reservation Status  \
# 0                       C                  C     Transient          Check-Out
# 1                       C                  C     Transient          Check-Out
# 2                       A                  C     Transient          Check-Out
# 3                       A                  A     Transient          Check-Out
# 4                       A                  A     Transient          Check-Out
# ...                   ...                ...           ...                ...
# 119385                  A                  A     Transient          Check-Out
# 119386                  E                  E     Transient          Check-Out
# 119387                  D                  D     Transient          Check-Out
# 119388                  A                  A     Transient          Check-Out
# 119389                  A                  A     Transient          Check-Out
#
#        Reservation status_date
# 0                   2015-07-01
# 1                   2015-07-01
# 2                   2015-07-02
# 3                   2015-07-02
# 4                   2015-07-03
# ...                        ...
# 119385              2017-09-06
# 119386              2017-09-07
# 119387              2017-09-07
# 119388              2017-09-07
# 119389              2017-09-07
#
# [119390 rows x 21 columns]

# %% [markdown]
# # Задание № 2
# Приведите названия колонок к нижнему регистру и замените пробелы на знак нижнего подчеркивания.

# %%
bookings.columns
# Out:
# Index(['Hotel', 'Is Canceled', 'Lead Time', 'arrival full date',
#        'Arrival Date Year', 'Arrival Date Month', 'Arrival Date Week Number',
#        'Arrival Date Day of Month', 'Stays in Weekend nights',
#        'Stays in week nights', 'stays total nights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'Reserved Room Type', 'Assigned room type',
#        'customer type', 'Reservation Status', 'Reservation status_date'],
#       dtype='object')

# %%
bookings = bookings.rename(columns={'Hotel': 'hotel',
                         'Is Canceled': 'is_canceled',
                         'Lead Time': 'lead_time',
                         'arrival full date': 'arrival_full_date',
                         'Arrival Date Month': 'arrival_date_month',
                         'Arrival Date Year': 'arrival_date_year',
                         'Arrival Date Week Number': 'arrival_date_week_number',
                         'Stays in Weekend nights': 'stays_in_weekend_nights',
                         'Stays in week nights': 'stays_in_week_nights',
                         'stays total nights': 'stays_total_nights',
                         'Adults': 'adults',
                         'Children': 'children',
                         'Babies': 'babies',
                         'Meal': 'meal',
                         'Country': 'country',
                         'Reserved Room Type': 'reserved_room_type',
                         'Assigned room type': 'assigned_room_type',
                         'customer type': 'customer_type',
                         'Reservation Status': 'reservation_status',
                         'Reservation status_date': 'reservation_status_date',
                         'Arrival Date Day of Month': 'arrival_date_day_of_month'})

# %% [markdown]
# # Задание № 3
# Пользователи из каких стран совершили наибольшее число успешных бронирований? Укажите топ-5.

# %%
bookings['is_canceled'] \
    .value_counts(dropna=False)
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
bookings \
    .query('is_canceled < 1') \
    .groupby(['country','is_canceled'], as_index=False) \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#     country  is_canceled
# 125     PRT        21071
# 57      GBR         9676
# 54      FRA         8481
# 50      ESP         6391
# 42      DEU         6069
# ..      ...          ...
# 138     SMR            1
# 101     MLI            1
# 136     SLE            1
# 94      MAC            1
# 122     PLW            1
#
# [165 rows x 2 columns]

# %% [markdown]
# # Задание № 4
# На сколько ночей в среднем бронируют отели разных типов?

# %%
bookings \
    .query('is_canceled < 1') \
    .query("hotel == 'Resort Hotel'") \
    .groupby(['hotel', 'is_canceled'], as_index=False) \
    .agg({'stays_total_nights': 'mean'}) \
    .round(2) \
    .sort_values('is_canceled', ascending=False)
# Out:
#           hotel  is_canceled  stays_total_nights
# 0  Resort Hotel            0                4.14

# %%
bookings \
    .query("hotel == 'Resort Hotel'") \
    .groupby(['hotel'], as_index=False) \
    .agg({'stays_total_nights': 'mean'}) \
    .round(2)
# Out:
#           hotel  stays_total_nights
# 0  Resort Hotel                4.32

# %%
bookings \
    .query('is_canceled < 1') \
    .query("hotel == 'City Hotel'") \
    .groupby(['hotel', 'is_canceled'], as_index=False) \
    .agg({'stays_total_nights': 'mean'}) \
    .round(2) \
    .sort_values('is_canceled', ascending=False)
# Out:
#         hotel  is_canceled  stays_total_nights
# 0  City Hotel            0                2.92

# %%
bookings \
    .query("hotel == 'City Hotel'") \
    .groupby(['hotel'], as_index=False) \
    .agg({'stays_total_nights': 'mean'}) \
    .round(2) \
# Out:
#         hotel  stays_total_nights
# 0  City Hotel                2.98

# %% [markdown]
# # Задание № 5
# Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга. Сколько подобных наблюдений встретилось в датасете?

# %%
bookings \
    .query("reserved_room_type != assigned_room_type")
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 2       Resort Hotel            0          7        2015-07-01
# 12      Resort Hotel            0         68        2015-07-01
# 15      Resort Hotel            0         68        2015-07-01
# 17      Resort Hotel            0         12        2015-07-01
# 18      Resort Hotel            0          0        2015-07-01
# ...              ...          ...        ...               ...
# 119273    City Hotel            0        213        2017-08-28
# 119274    City Hotel            0        213        2017-08-28
# 119289    City Hotel            0         25        2017-08-30
# 119297    City Hotel            0        332        2017-08-31
# 119357    City Hotel            0         47        2017-08-31
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 2                    2015               July                        27
# 12                   2015               July                        27
# 15                   2015               July                        27
# 17                   2015               July                        27
# 18                   2015               July                        27
# ...                   ...                ...                       ...
# 119273               2017             August                        35
# 119274               2017             August                        35
# 119289               2017             August                        35
# 119297               2017             August                        35
# 119357               2017             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 2                               1                        0
# 12                              1                        0
# 15                              1                        0
# 17                              1                        0
# 18                              1                        0
# ...                           ...                      ...
# 119273                         28                        1
# 119274                         28                        1
# 119289                         30                        0
# 119297                         31                        0
# 119357                         31                        1
#
#         stays_in_week_nights  ...  babies  meal  country  reserved_room_type  \
# 2                          1  ...       0    BB      GBR                   A
# 12                         4  ...       0    BB      USA                   D
# 15                         4  ...       0    BB      IRL                   D
# 17                         1  ...       0    BB      IRL                   A
# 18                         1  ...       0    BB      FRA                   A
# ...                      ...  ...     ...   ...      ...                 ...
# 119273                     3  ...       0    HB      PRT                   A
# 119274                     3  ...       0    HB      PRT                   A
# 119289                     3  ...       0    BB      ITA                   E
# 119297                     2  ...       0    BB      GBR                   D
# 119357                     3  ...       0    SC      PRT                   A
#
#        assigned_room_type    customer_type reservation_status  \
# 2                       C        Transient          Check-Out
# 12                      E        Transient          Check-Out
# 15                      E        Transient          Check-Out
# 17                      E        Transient          Check-Out
# 18                      G        Transient          Check-Out
# ...                   ...              ...                ...
# 119273                  K  Transient-Party          Check-Out
# 119274                  K  Transient-Party          Check-Out
# 119289                  F        Transient          Check-Out
# 119297                  F        Transient          Check-Out
# 119357                  D        Transient          Check-Out
#
#        reservation_status_date total_kids has_kids
# 2                   2015-07-02        0.0    False
# 12                  2015-07-05        0.0    False
# 15                  2015-07-05        0.0    False
# 17                  2015-07-02        0.0    False
# 18                  2015-07-02        0.0    False
# ...                        ...        ...      ...
# 119273              2017-09-01        0.0    False
# 119274              2017-09-01        0.0    False
# 119289              2017-09-02        0.0    False
# 119297              2017-09-02        0.0    False
# 119357              2017-09-04        0.0    False
#
# [14917 rows x 23 columns]

# %% [markdown]
# # Задание № 6
# Проанализируйте даты запланированного прибытия. – На какой месяц чаще всего успешно оформляли бронь в 2016? Изменился ли самый популярный месяц в 2017?– Сгруппируйте данные по годам и проверьте, на какой месяц бронирования отеля типа City Hotel отменялись чаще всего в каждый из периодов

# %%
bookings \
    .query("arrival_date_year == '2016'") \
    .groupby(['arrival_date_year', 'arrival_date_month', 'is_canceled'], as_index=False) \
    .agg({'is_canceled': 'sum'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 21               2016            October         2514
# 13               2016               June         2096
# 1                2016              April         2061
# 23               2016          September         2022
# 17               2016                May         1915
# 3                2016             August         1825
# 19               2016           November         1636
# 11               2016               July         1499
# 15               2016              March         1477
# 5                2016           December         1398
# 7                2016           February         1337
# 9                2016            January          557
# 16               2016                May            0
# 22               2016          September            0
# 20               2016            October            0
# 18               2016           November            0
# 0                2016              April            0
# 14               2016              March            0
# 10               2016               July            0
# 8                2016            January            0
# 6                2016           February            0
# 4                2016           December            0
# 2                2016             August            0
# 12               2016               June            0

# %%
bookings \
    .query("arrival_date_year == '2017'") \
    .groupby(['arrival_date_year', 'arrival_date_month', 'is_canceled'], as_index=False) \
    .agg({'is_canceled': 'sum'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 15               2017                May         2762
# 1                2017              April         2463
# 11               2017               June         2439
# 9                2017               July         1984
# 3                2017             August         1816
# 13               2017              March         1672
# 5                2017           February         1359
# 7                2017            January         1250
# 0                2017              April            0
# 2                2017             August            0
# 4                2017           February            0
# 6                2017            January            0
# 8                2017               July            0
# 10               2017               June            0
# 12               2017              March            0
# 14               2017                May            0

# %%
bookings \
    .query('is_canceled > 0') \
    .query("hotel == 'City Hotel'") \
    .query("arrival_date_year == '2015'") \
    .groupby(['hotel', 'arrival_date_month', 'is_canceled'], as_index=False) \
    .agg({'is_canceled': 'sum'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#         hotel arrival_date_month  is_canceled
# 5  City Hotel          September         1543
# 4  City Hotel            October         1321
# 0  City Hotel             August         1232
# 2  City Hotel               July          939
# 1  City Hotel           December          668
# 3  City Hotel           November          301

# %%
bookings \
    .query('is_canceled > 0') \
    .query("hotel == 'City Hotel'") \
    .query("arrival_date_year == '2016'") \
    .groupby(['hotel', 'arrival_date_month', 'is_canceled'], as_index=False) \
    .agg({'is_canceled': 'sum'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#          hotel arrival_date_month  is_canceled
# 10  City Hotel            October         1947
# 6   City Hotel               June         1720
# 11  City Hotel          September         1567
# 0   City Hotel              April         1539
# 8   City Hotel                May         1436
# 9   City Hotel           November         1360
# 1   City Hotel             August         1247
# 7   City Hotel              March         1108
# 2   City Hotel           December         1072
# 5   City Hotel               July         1043
# 3   City Hotel           February          930
# 4   City Hotel            January          438

# %%
bookings \
    .query('is_canceled > 0') \
    .query("hotel == 'City Hotel'") \
    .query("arrival_date_year == '2017'") \
    .groupby(['hotel', 'arrival_date_month', 'is_canceled'], as_index=False) \
    .agg({'is_canceled': 'sum'}) \
    .sort_values('is_canceled', ascending=False) \
# Out:
#         hotel arrival_date_month  is_canceled
# 7  City Hotel                May         2217
# 0  City Hotel              April         1926
# 5  City Hotel               June         1808
# 4  City Hotel               July         1324
# 6  City Hotel              March         1278
# 1  City Hotel             August         1123
# 3  City Hotel            January         1044
# 2  City Hotel           February          971

# %% [markdown]
# # Задание № 7
# Посмотрите на числовые характеристики трёх переменных: adults, children и babies. Какая из них имеет наибольшее среднее значение?

# %%
bookings[['adults', 'children', 'babies']] \
    .mean() \
    .idxmax()
# Out:
# 'adults'

# %% [markdown]
# # Задание № 8
# Создайте колонку total_kids, объединив children и babies. Для отелей какого типа среднее значение переменной оказалось наибольшим?

# %%
bookings['total_kids'] = bookings[['children', 'babies']].sum(axis=1)

# %%
bookings \
    .query("hotel == 'City Hotel'") \
    .groupby(['hotel'], as_index=False) \
    .agg({'total_kids': 'mean'}) \
    .round(2)
# Out:
#         hotel  total_kids
# 0  City Hotel         0.1

# %%
bookings \
    .query("hotel == 'Resort Hotel'") \
    .groupby(['hotel'], as_index=False) \
    .agg({'total_kids': 'mean'}) \
    .round(2)
# Out:
#           hotel  total_kids
# 0  Resort Hotel        0.14

# %% [markdown]
# # Задание № 9
# Создайте переменную has_kids, которая принимает значение True, если клиент при бронировании указал хотя бы одного ребенка (total_kids), в противном случае – False. Посчитайте отношение количества ушедших пользователей к общему количеству клиентов, выраженное в процентах (метрика - churn rate). Укажите, среди какой группы показатель выше.

# %%
bookings['has_kids'] = bookings['total_kids']

# %%
bookings = bookings.astype({"has_kids": "Int64"})

# %%
bookings.has_kids = bookings.total_kids > 0

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# 2                    2015               July                        27
# 3                    2015               July                        27
# 4                    2015               July                        27
# ...                   ...                ...                       ...
# 119385               2017             August                        35
# 119386               2017             August                        35
# 119387               2017             August                        35
# 119388               2017             August                        35
# 119389               2017             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  ...  babies  meal  country  reserved_room_type  \
# 0                          0  ...       0    BB      PRT                   C
# 1                          0  ...       0    BB      PRT                   C
# 2                          1  ...       0    BB      GBR                   A
# 3                          1  ...       0    BB      GBR                   A
# 4                          2  ...       0    BB      GBR                   A
# ...                      ...  ...     ...   ...      ...                 ...
# 119385                     5  ...       0    BB      BEL                   A
# 119386                     5  ...       0    BB      FRA                   E
# 119387                     5  ...       0    BB      DEU                   D
# 119388                     5  ...       0    BB      GBR                   A
# 119389                     7  ...       0    HB      DEU                   A
#
#        assigned_room_type customer_type reservation_status  \
# 0                       C     Transient          Check-Out
# 1                       C     Transient          Check-Out
# 2                       C     Transient          Check-Out
# 3                       A     Transient          Check-Out
# 4                       A     Transient          Check-Out
# ...                   ...           ...                ...
# 119385                  A     Transient          Check-Out
# 119386                  E     Transient          Check-Out
# 119387                  D     Transient          Check-Out
# 119388                  A     Transient          Check-Out
# 119389                  A     Transient          Check-Out
#
#        reservation_status_date total_kids has_kids
# 0                   2015-07-01        0.0    False
# 1                   2015-07-01        0.0    False
# 2                   2015-07-02        0.0    False
# 3                   2015-07-02        0.0    False
# 4                   2015-07-03        0.0    False
# ...                        ...        ...      ...
# 119385              2017-09-06        0.0    False
# 119386              2017-09-07        0.0    False
# 119387              2017-09-07        0.0    False
# 119388              2017-09-07        0.0    False
# 119389              2017-09-07        0.0    False
#
# [119390 rows x 23 columns]

# %%
bookings \
    .query('has_kids == True') \
    .groupby(['has_kids', 'is_canceled'], as_index=False) \
    .agg({'has_kids': 'count'})
# Out:
#    is_canceled  has_kids
# 0            0      6073
# 1            1      3259

# %%
round((3259 / (3259 + 6073))*100, 2)
# Out:
# 34.92

# %%
bookings \
    .query('has_kids == False') \
    .groupby(['has_kids', 'is_canceled'], as_index=False) \
    .agg({'has_kids': 'count'})
# Out:
#    is_canceled  has_kids
# 0            0     69093
# 1            1     40965

# %%
round((40965 / (69093+40965))*100, 2)
# Out:
# 37.22
